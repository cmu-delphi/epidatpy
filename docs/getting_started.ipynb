# %% [markdown]
# # Getting started
#
# The epidatpy package provides Python access to all the endpoints of the
# [Delphi Epidata API](https://cmu-delphi.github.io/delphi-epidata/): current
# surveillance signals, their revision history, and the metadata describing
# them.
#
# ## The Delphi V5 API
#
# The V5 API has three ways to access data:
#
# - `epidata_snapshot()` time-travels to how a dataset looked at a point in time.
# - `epidata_archive()` fetches every revision of a dataset up to a point in
#   time. Each row is a "diff" -- a point where the value for a given key changed.
# - `epidata_aux()` accesses source-specific auxiliary tables: metadata,
#   laboratory protocols, or extra static keys (e.g. NWSS wastewater facility
#   descriptions).
#
# `epidata_meta()` rounds these out with metadata: the available sources,
# signals, geographic levels, and date ranges.

# %%
# Hidden cell (set in the metadata for this cell)
import pandas as pd

# Set common options and context
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 10)
pd.set_option("display.width", 1000)

# %% [markdown]
# ## Basic usage
#
# Suppose we are interested in the `nssp` source, which provides a
# [wide range of](https://cmu-delphi.github.io/delphi-epidata/api/v5-signals/nssp.html)
# emergency department visits data. To request this source at a point in time,
# `epidata_snapshot()` needs a signal name and a geographic level.

# %%
from epidatpy import EpiDataContext, EpiRange

# Create the client. With `use_cache=True` results are cached to disk for
# 7 days, which avoids repeated downloads.
epidata = EpiDataContext(use_cache=True, cache_max_age_days=7)

# `epidata_snapshot` returns an `EpiDataCall`: a not-yet-executed query.
apicall = epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="nation",
)
print(apicall)

# Execute it and get a DataFrame with `.df()`.
apicall.df()

# %% [markdown]
# `epidata_snapshot()` returns a `pandas.DataFrame`. Each row is one observation
# for one location on one date. The location is in `geo_value`, the date it
# describes in `reference_time`. `value` is the requested signal -- here the
# percentage of emergency department visits with an influenza diagnosis -- and
# `report_time` is the date this version of the value was published.
#
# The V5 API makes signals available at different geographic levels, depending
# on the source. To request all states instead of the whole US, change
# `geo_type`; the snapshot returns every location available at that level. Check
# `epidata.epidata_meta("nssp")` to see which geo types a source supports.

# %%
epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
).df()

# %% [markdown]
# Alternatively, fetch a subset of states over a bounded window by listing the
# locations in `geo_values` and passing an `EpiRange` to `reference_time` (both
# are applied locally after the fetch):

# %%
# Influenza ED-visit percentage from NSSP for PA, CA, and FL,
# for reference dates in 2024.
epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa,ca,fl",
    reference_time=EpiRange("2024-01-01", "2025-01-01"),
).df()

# %% [markdown]
# ## Getting versioned data
#
# The V5 API keeps a historical record of all data, including corrections and
# updates -- useful for backtesting forecasting models. `epidata_snapshot()`
# takes a `snapshot_date` argument that fetches the data as it was known on a
# given date.

# %%
# Influenza ED-visit percentage from NSSP for PA, as it was known on 2025-01-01.
epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa",
    snapshot_date="2025-01-01",
).df()

# %% [markdown]
# To pull *every* version issued in a time range, use `epidata_archive()` with
# `report_time`. It accepts an exact date, a comparison string like
# `"<2025-01-01"`, or an `EpiRange`.

# %%
# How the estimate for a single reference date (2024-12-07) evolved,
# across every report issued from December 2024 to mid-January 2025.
epidata.epidata_archive(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa",
    reference_time="2024-12-07",
    report_time=EpiRange("2024-12-01", "2025-01-15"),
).df()

# %% [markdown]
# See the [versioned data guide](versioned_data.ipynb) for more ways to specify
# versions, and the [migration guide](migration_guide.ipynb) for the full
# `pub_covidcast()` argument mapping.
#
# ## Auxiliary data
#
# Some sources carry extra columns tied to the signal data, such as the
# population served by each NWSS sewershed or its site metadata. `epidata_aux()`
# retrieves this auxiliary data, either on its own or merged onto a signal pull.
#
# The snippets in this section are shown but not run: `epidata_aux()` is not yet
# part of the released package.
#
# Pull auxiliary data directly by source. Named filters on key columns narrow
# the rows returned, and `columns` selects specific fields:
#
# ```python
# aux_data = epidata.epidata_aux(
#     "nwss",
#     pcr_target="sars-cov-2",
#     sample_index=["92012", "92013"],
# ).df()
# aux_data.head()
# ```
#
# You can also attach auxiliary columns to a signal pull by passing an
# `epidata_snapshot()` or `epidata_archive()` result straight to
# `epidata_aux()`. It fetches the matching auxiliary data and left-joins it on
# the shared key columns:
#
# ```python
# nwss_data = epidata.epidata_snapshot(
#     source="nwss",
#     signals="covid_avg_conc",
#     geo_type="sewershed",
#     geo_values="128",
#     reference_time=EpiRange("2024-12-01", "2025-01-01"),
# ).df()
#
# epidata.epidata_aux(nwss_data).head()
# ```
#
# If you don't pass explicit key filters, `epidata_aux()` infers them from the
# base dataset.
#
# ## Advanced queries
#
# ### Server-side key filtering
#
# Sources with multi-dimensional keys (such as `nwss`, which keys on
# `pcr_target`) will support filtering on those keys directly in
# `epidata_snapshot()` and `epidata_archive()`:
#
# ```python
# epidata.epidata_snapshot(
#     source="nwss",
#     signals="pcr_conc_smoothed",
#     geo_type="county",
#     pcr_target=["sars-cov-2", "influenza"],
# ).df()
# ```
#
# ### Inspecting a query without fetching
#
# An `EpiDataCall` is lazy. Print it, or read `request_url()`, to see the
# generated request without hitting the server:

# %%
apicall = epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
)
print(apicall)
print(apicall.request_url())

# %% [markdown]
# ## Plotting
#
# The result is a standard pandas DataFrame, so any plotting library works:

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 300

df = epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa,ca,fl",
    reference_time=EpiRange("2023-10-01", "2024-06-01"),
).df()

fig, ax = plt.subplots(figsize=(6, 5))
for spine in ("right", "left", "top"):
    ax.spines[spine].set_visible(False)

df.pivot_table(values="value", index="reference_time", columns="geo_value").plot(
    xlabel="Date", ylabel="% of ED visits", ax=ax, linewidth=1.5
)

plt.title("Influenza ED visits from NSSP", fontsize=16)
plt.subplots_adjust(bottom=0.2)
plt.show()

# %% [markdown]
# ## Available data sources and endpoints
#
# epidatpy reaches a broad ecosystem of epidemiological data streams:
#
# - **V5 sources** -- active surveillance data queried with `epidata_snapshot()`
#   and `epidata_archive()`. Discover them with `epidata_meta()` or on the
#   [Delphi EpiPortal](https://delphi.cmu.edu/epiportal/).
# - **Migrating endpoints** -- legacy endpoints (`pub_covidcast()`,
#   `pub_fluview()`, `pub_flusurv()`, `pub_meta()`, ...) transitioning to V5. See
#   the [migration guide](migration_guide.ipynb) for the argument mapping.
# - **Historical endpoints** -- datasets whose collection has ended (Google Flu
#   Trends, Wikipedia article views, historical hospitalization series), kept for
#   retrospective analysis via `pub_*` functions.
#   - **International endpoints** -- a subset of the historical datasets covering
#     surveillance outside the US (`pub_paho_dengue()`, `pub_ecdc_ili()`, ...).
#   - **Private endpoints** -- restricted streams (`pvt_cdc()`, `pvt_sensors()`,
#     ...) that need a dedicated secret key.
#
# See the [signal discovery guide](signal_discovery.ipynb) for how to browse and
# query across all of these.
#
# ## Epiweeks and dates
#
# Formatting for epiweeks is YYYYWW and for dates is YYYYMMDD.
#
# Epiweeks use the U.S. CDC definition: the first epiweek of the year is the
# first week containing January 4th, and weeks start on Sunday. See [this
# page](https://www.cmmcp.org/mosquito-surveillance-data/pages/epi-week-calendars-2008-2021)
# for a longer explanation.
#
# For a time argument you can pass individual values, comma-separated lists, or a
# hyphenated range, and an `EpiRange` object also works. Examples:
#
# - `param = 201530` (a single epiweek)
# - `param = "201401,201501,201601"` (several epiweeks)
# - `param = "200501-200552"` (a range of epiweeks)
# - `param = "201440,201501-201510"` (several epiweeks, including a range)
# - `param = EpiRange(20070101, 20071231)` (a range of dates)
