# %% [markdown]
# # Accessing versioned data
#
# The Delphi Epidata API records not just each signal's estimate for a given
# location on a given date, but also *when* that estimate was made, and every
# update to it.
#
# For example, take the [emergency department visits
# signal](https://cmu-delphi.github.io/delphi-epidata/api/v5-signals/nssp.html)
# from the `nssp` source, which estimates the percentage of ED visits that are
# influenza-related. Consider a row with `reference_time` 2024-12-07 for
# `geo_values = "pa"`: an estimate for Pennsylvania on December 7, 2024. That
# estimate was first *reported* (published) on December 13, 2024 -- the delay
# being the time our source takes to aggregate the data and the API takes to
# ingest it. The estimate for December 7th was later updated as more visit data
# arrived. Each update is a new *version* of the data.
#
# ## Data known "as of" a specific date
#
# By default, endpoint functions fetch the most recent data available -- best
# for graphing the latest data or building dashboards. To ask *when* data was
# reported, request specific versions with `snapshot_date` in
# `epidata_snapshot()` or `report_time` in `epidata_archive()`.
#
# First, request the data available *as of* a specific date with `snapshot_date`:

# %%
# Hidden cell (set in the metadata for this cell)
import pandas as pd

# Set common options and context
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 10)
pd.set_option("display.width", 1000)

# %%
from epidatpy import EpiDataContext, EpiRange

epidata = EpiDataContext(use_cache=False)

past_snapshot = epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa",
    reference_time="2024-12-07",
    snapshot_date="2024-12-14",
).df()
past_snapshot

# %% [markdown]
# That is the estimate that was known as of December 14. Without `snapshot_date`,
# we get the most recent estimate available:

# %%
latest_snapshot = epidata.epidata_snapshot(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa",
    reference_time="2024-12-07",
).df()
latest_snapshot

# %% [markdown]
# The estimate changed between the two versions, reflecting new data that
# arrived after December 14 about visits *occurring on* December 7. This is why
# version tracking matters for forecasting: to backtest a model you must use the
# data that would have been available *at the time*, not data that landed later.
#
# Plotting a signal at several `snapshot_date` values shows how the estimates
# firm up as observations arrive:

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 300

frames = []
for snapshot_date in ["2024-11-15", "2024-12-01", "2024-12-15", "2025-01-01"]:
    df = epidata.epidata_snapshot(
        source="nssp",
        signals="pct_ed_visits_influenza",
        geo_type="state",
        geo_values="pa",
        reference_time=EpiRange("2024-10-01", "2024-11-15"),
        snapshot_date=snapshot_date,
    ).df()
    df["snapshot_date"] = snapshot_date
    frames.append(df)

final_df = pd.concat(frames)

fig, ax = plt.subplots(figsize=(6, 5))
for spine in ("right", "left", "top"):
    ax.spines[spine].set_visible(False)

final_df.pivot_table(
    values="value", index="reference_time", columns="snapshot_date"
).plot(xlabel="Reference date", ylabel="% of ED visits", ax=ax, linewidth=1.5)

plt.title("NSSP influenza ED visits, by snapshot date", fontsize=16)
plt.subplots_adjust(bottom=0.2)
plt.show()

# %% [markdown]
# ## Multiple versions and revision histories
#
# `epidata_archive()` with a `report_time` range returns every version reported
# in that window:

# %%
archive_data = epidata.epidata_archive(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa",
    reference_time="2024-12-07",
    report_time=EpiRange("2024-12-01", "2025-01-15"),
).df()
archive_data

# %% [markdown]
# The estimate was updated several times as new data for December 7th arrived.
# These results include only versions reported between (inclusive) 2024-12-01
# and 2025-01-15: a value first reported outside that window is not included.
#
# `report_time` also accepts comparison operators such as `"<2025-01-01"`, or an
# exact date:

# %%
epidata.epidata_archive(
    source="nssp",
    signals="pct_ed_visits_influenza",
    geo_type="state",
    geo_values="pa",
    reference_time="2024-12-07",
    report_time="<2025-01-01",
).df()

# %% [markdown]
# ## Calculating reporting lag
#
# In the V5 API, reporting lag is just the difference between `report_time` (the
# publication date) and `reference_time` (the observation date):

# %%
archive_with_lag = archive_data.assign(
    lag_days=(archive_data["report_time"] - archive_data["reference_time"]).dt.days
)[["signal", "reference_time", "report_time", "lag_days", "value"]]

archive_with_lag

# %% [markdown]
# To simulate data available with at most a given delay (say 14 days), filter on
# `lag_days`:

# %%
archive_with_lag[archive_with_lag["lag_days"] <= 14]

# %% [markdown]
# ## Migrating from legacy endpoints
#
# For sources that have not yet moved off the legacy V4 API, versioning is
# specified through `pub_covidcast()` with `as_of`, `issues`, or `lag`:

# %%
# Legacy V4 query using `as_of`. Emits a deprecation warning.
epidata.pub_covidcast(
    data_source="fb-survey",
    signals="smoothed_accept_covid_vaccine",
    geo_type="state",
    geo_values="pa",
    time_type="day",
    time_values=EpiRange(20201221, 20201225),
    as_of=20201231,
).df()

# %% [markdown]
# See the [migration guide](migration_guide.ipynb) for the full argument and
# column mapping between V4 and V5.
